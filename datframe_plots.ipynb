# %% [markdown]
# # Python Data Frame Visualizations
#
# #### This Notebook doesn't use any package for Visualizations

# %%
import pandas as pd
pd.__version__
# Out:
# '2.0.0'

# %%
df_students=pd.read_parquet('students.parquet', engine='pyarrow', dtype_backend='pyarrow')
df_students.rename(columns={'race/ethnicity':'race'},inplace=True)
df_students
# Out:
#      gender     race parental level of education         lunch
# 0    female  group B           bachelor's degree      standard  \
# 1    female  group C                some college      standard
# 2    female  group B             master's degree      standard
# 3      male  group A          associate's degree  free/reduced
# 4      male  group C                some college      standard
# ..      ...      ...                         ...           ...
# 995  female  group E             master's degree      standard
# 996    male  group C                 high school  free/reduced
# 997  female  group C                 high school  free/reduced
# 998  female  group D                some college      standard
# 999  female  group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# ...

# %% [markdown]
# ### Pandas DataFrame has these available options with Plot() :
# ##### 1.Line
# ##### 2.Bar
# ##### 3.Boxplot
# ##### 4.Pie
# ##### 5.Kde/Density
# ##### 6.Hexagonal Bin
# ##### 7.Histogram
# ##### 8.Area
# ##### 9.Scatter

# %%
### Line Plot

df_students['math score'].plot(kind='line', title='Line Plot for Math Score')
# Out:
# <AxesSubplot: title={'center': 'Line Plot for Math Score'}>

# %%
df_students.plot(kind='line', title='Line Plot for Scores')
# Out:
# <AxesSubplot: title={'center': 'Line Plot for Scores'}>

# %%
df_students.plot(kind='line', title='Line Plot for Scores', subplots=True)
# Out:
# array([<AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >], dtype=object)

# %%
df_students.plot(kind='hist', title='Histogram Plot for Scores', subplots=True)
# Out:
# array([<AxesSubplot: ylabel='Frequency'>,
#        <AxesSubplot: ylabel='Frequency'>,
#        <AxesSubplot: ylabel='Frequency'>], dtype=object)

# %%
df_students['gender'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='gender'>

# %%
df_students['gender'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot: ylabel='gender'>

# %%
df_students['math score'].plot(kind='hist')
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df_students['writing score'].plot(kind='box')
# Out:
# <AxesSubplot: >

# %%
df_students.plot(kind='box')
# Out:
# <AxesSubplot: >

# %%
df_students.groupby('parental level of education').plot(kind='box', subplots=True)
# Out:
#                                                         math score
# parental level of education
# associate's degree           AxesSubplot(0.125,0.11;0.227941x0.77)  \
# bachelor's degree            AxesSubplot(0.125,0.11;0.227941x0.77)
# high school                  AxesSubplot(0.125,0.11;0.227941x0.77)
# master's degree              AxesSubplot(0.125,0.11;0.227941x0.77)
# some college                 AxesSubplot(0.125,0.11;0.227941x0.77)
# some high school             AxesSubplot(0.125,0.11;0.227941x0.77)
#
#                                                         reading score
# parental level of education
# associate's degree           AxesSubplot(0.398529,0.11;0.227941x0.77)  \
# bachelor's degree            AxesSubplot(0.398529,0.11;0.227941x0.77)
# high school                  AxesSubplot(0.398529,0.11;0.227941x0.77)
# master's degree              AxesSubplot(0.398529,0.11;0.227941x0.77)
# some college                 AxesSubplot(0.398529,0.11;0.227941x0.77)
# ...

# %%
df_students.plot(x='math score', y='reading score',kind='hexbin')
# Out:
# <AxesSubplot: xlabel='math score', ylabel='reading score'>

# %%
df_student_stats=pd.DataFrame(df_students.describe())
df_student_stats=df_student_stats.loc[['std','mean','50%','75%']]
df_student_stats
df_student_stats.plot.pie(y='math score')
# Out:
# <AxesSubplot: ylabel='math score'>

# %%
df_students.groupby('lunch').size().plot(kind='pie')
# Out:
# <AxesSubplot: >

# %%
df_students.groupby('race').size().plot(kind='pie',autopct='%.2f')
# Out:
# <AxesSubplot: >

# %%
df_students['math score'].plot(kind='line')
# Out:
# <AxesSubplot: >

# %%
df_students['math score'].plot(kind='area')
# Out:
# <AxesSubplot: >

# %%
df_students.plot(x='math score', y='reading score', kind='scatter')
# Out:
# <AxesSubplot: xlabel='math score', ylabel='reading score'>

# %%
df_students.groupby('lunch').size().plot(kind='pie')
# Out:
# <AxesSubplot: >

# %%
from statsmodels.graphics.mosaicplot import mosaic

mosaic(df_students,['gender','race','lunch'])
# Out:
# (<Figure size 640x480 with 3 Axes>,
#  {('female', 'group B', 'standard'): (0.0,
#    0.0,
#    0.32142502564781417,
#    0.19813046128835604),
#   ('female', 'group B', 'free/reduced'): (0.32256787018345084,
#    0.0,
#    0.19285501538868852,
#    0.19813046128835604),
#   ('female', 'group C', 'standard'): (0.0,
#    0.20141993497256655,
#    0.3371391380128184,
#    0.3429181060760009),
#   ('female', 'group C', 'free/reduced'): (0.3382819825484551,
#    0.20141993497256655,
#    0.17714090302368427,
#    0.3429181060760009),
#   ('female', 'group A', 'standard'): (0.0,
#    0.547627514732778,
#    0.314282247300085,
#    0.06858362121520015),
#   ('female', 'group A', 'free/reduced'): (0.31542509183572165,
#    0.547627514732778,
#    0.19999779373641768,
#    0.06858362121520015),
#   ('female', 'group D', 'standard'): (0.0,
#    0.6195006096321887,
#    0.3109600248127691,
#    0.245757976021134),
#   ('female', 'group D', 'free/reduced'): (0.31210286934840575,
# ...
